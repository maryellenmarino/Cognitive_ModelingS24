# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
priors = np.linspace(0.01,1,100)

# %%
def posteriorFromPrior(prior):
    sensitivity = 0.95
    specificity = 0.90
    probTruePositive = prior*sensitivity
    probFalsePositive = (1-prior)*(1-specificity)
    probPosTest = probTruePositive+probFalsePositive
    normalizedTruePositive = probTruePositive/probPosTest;
    return normalizedTruePositive

# %%
posteriorValues = posteriorFromPrior(priors)

# %%
posteriorValues
# Out:
# array([0.0875576 , 0.16239316, 0.22709163, 0.28358209, 0.33333333,
#        0.37748344, 0.4169279 , 0.45238095, 0.48441926, 0.51351351,
#        0.54005168, 0.56435644, 0.58669834, 0.60730594, 0.62637363,
#        0.6440678 , 0.6605317 , 0.67588933, 0.69024857, 0.7037037 ,
#        0.71633752, 0.728223  , 0.7394247 , 0.75      , 0.76      ,
#        0.7694704 , 0.7784522 , 0.78698225, 0.7950938 , 0.8028169 ,
#        0.81017882, 0.8172043 , 0.8239159 , 0.83033419, 0.83647799,
#        0.84236453, 0.84800965, 0.8534279 , 0.85863268, 0.86363636,
#        0.86845039, 0.87308534, 0.87755102, 0.88185654, 0.88601036,
#        0.89002037, 0.89389389, 0.8976378 , 0.90125847, 0.9047619 ,
#        0.9081537 , 0.91143911, 0.91462307, 0.9177102 , 0.92070485,
#        0.92361111, 0.92643285, 0.92917369, 0.93183707, 0.93442623,
#        0.93694422, 0.93939394, 0.94177813, 0.94409938, 0.94636015,
#        0.94856278, 0.95070948, 0.95280236, 0.95484341, 0.95683453,
# ...

# %%
plt.title("Prior vs. Posterior") 
plt.xlabel("Percent of Population with Disease") 
plt.ylabel("Probability of having Disease Given Positive Test")  
plt.plot(priors, posteriorValues, color ="maroon")

# %%
sensitivities = np.linspace(0.01,1,100)

# %%
def posteriorFromSensitivity(sensitivity):
    prior = 0.01
    specificity = 0.90
    probTruePositive = prior*sensitivity
    probFalsePositive = (1-prior)*(1-specificity)
    probPosTest = probTruePositive+probFalsePositive
    normalizedTruePositive = probTruePositive/probPosTest;
    return normalizedTruePositive

# %%
posteriorValues1 = posteriorFromSensitivity(sensitivities)

# %%
posteriorValues1
# Out:
# array([0.00100908, 0.00201613, 0.00302115, 0.00402414, 0.00502513,
#        0.0060241 , 0.00702106, 0.00801603, 0.00900901, 0.01      ,
#        0.01098901, 0.01197605, 0.01296112, 0.01394422, 0.01492537,
#        0.01590457, 0.01688183, 0.01785714, 0.01883053, 0.01980198,
#        0.02077151, 0.02173913, 0.02270484, 0.02366864, 0.02463054,
#        0.02559055, 0.02654867, 0.02750491, 0.02845927, 0.02941176,
#        0.03036239, 0.03131115, 0.03225806, 0.03320313, 0.03414634,
#        0.03508772, 0.03602726, 0.03696498, 0.03790087, 0.03883495,
#        0.03976722, 0.04069767, 0.04162633, 0.04255319, 0.04347826,
#        0.04440154, 0.04532305, 0.04624277, 0.04716073, 0.04807692,
#        0.04899135, 0.04990403, 0.05081496, 0.05172414, 0.05263158,
#        0.05353728, 0.05444126, 0.05534351, 0.05624404, 0.05714286,
#        0.05803996, 0.05893536, 0.05982906, 0.06072106, 0.06161137,
#        0.0625    , 0.06338694, 0.06427221, 0.06515581, 0.06603774,
# ...

# %%
plt.title("Sensitivity vs. Posterior") 
plt.xlabel("Probability of a True Positive") 
plt.ylabel("Probability of having Disease Given Positive Test") 
plt.plot(sensitivities, posteriorValues1, color ="maroon")

# %%
specificities = np.linspace(0.01,1,100)

# %%
def posteriorFromSpecificity(specificity):
    prior = 0.01
    sensitivity = 0.95
    probTruePositive = prior*sensitivity
    probFalsePositive = (1-prior)*(1-specificity)
    probPosTest = probTruePositive+probFalsePositive
    normalizedTruePositive = probTruePositive/probPosTest;
    return normalizedTruePositive

# %%
posteriorValues2 = posteriorFromSpecificity(specificities)

# %%
posteriorValues2
# Out:
# array([0.00959984, 0.00969685, 0.00979583, 0.00989686, 0.01      ,
#        0.01010531, 0.01021286, 0.01032272, 0.01043497, 0.01054969,
#        0.01066697, 0.01078687, 0.01090951, 0.01103496, 0.01116334,
#        0.01129473, 0.01142926, 0.01156703, 0.01170816, 0.01185278,
#        0.01200101, 0.012153  , 0.01230889, 0.01246883, 0.01263298,
#        0.01280151, 0.0129746 , 0.01315243, 0.0133352 , 0.01352313,
#        0.01371643, 0.01391534, 0.0141201 , 0.01433097, 0.01454824,
#        0.0147722 , 0.01500316, 0.01524146, 0.01548745, 0.01574151,
#        0.01600404, 0.01627548, 0.01655629, 0.01684696, 0.01714801,
#        0.01746003, 0.0177836 , 0.0181194 , 0.01846812, 0.01883053,
#        0.01920744, 0.01959975, 0.02000842, 0.0204345 , 0.02087912,
#        0.02134352, 0.02182904, 0.02233717, 0.02286952, 0.02342787,
#        0.02401416, 0.02463054, 0.0252794 , 0.02596338, 0.02668539,
#        0.02744871, 0.02825699, 0.02911431, 0.03002528, 0.03099511,
# ...

# %%
plt.title("Specificity vs. Posterior") 
plt.xlabel("Probability of a True Negative") 
plt.ylabel("Probability of having Disease Given Positive Test") 
plt.plot(specificities, posteriorValues2, color ="maroon")

# %%
def posteriorFromPriorAndSensitivity(prior, sensitivity):
    specificity = 0.9
    probTruePositive = prior*sensitivity
    probFalsePositive = (1-prior)*(1-specificity)
    probPosTest = probTruePositive+probFalsePositive
    normalizedTruePositive = probTruePositive/probPosTest;
    return normalizedTruePositive

# %%
#https://www.geeksforgeeks.org/3d-surface-plotting-in-python-using-matplotlib/
X, Y = np.meshgrid(priors, sensitivities)
X,Y
# Out:
# (array([[0.01, 0.02, 0.03, ..., 0.98, 0.99, 1.  ],
#         [0.01, 0.02, 0.03, ..., 0.98, 0.99, 1.  ],
#         [0.01, 0.02, 0.03, ..., 0.98, 0.99, 1.  ],
#         ...,
#         [0.01, 0.02, 0.03, ..., 0.98, 0.99, 1.  ],
#         [0.01, 0.02, 0.03, ..., 0.98, 0.99, 1.  ],
#         [0.01, 0.02, 0.03, ..., 0.98, 0.99, 1.  ]]),
#  array([[0.01, 0.01, 0.01, ..., 0.01, 0.01, 0.01],
#         [0.02, 0.02, 0.02, ..., 0.02, 0.02, 0.02],
#         [0.03, 0.03, 0.03, ..., 0.03, 0.03, 0.03],
#         ...,
#         [0.98, 0.98, 0.98, ..., 0.98, 0.98, 0.98],
#         [0.99, 0.99, 0.99, ..., 0.99, 0.99, 0.99],
#         [1.  , 1.  , 1.  , ..., 1.  , 1.  , 1.  ]]))

# %%
posteriors = posteriorFromPriorAndSensitivity(X,Y)

# %%
fig = plt.figure(figsize =(6, 6))
ax = plt.axes(projection ='3d')
my_cmap = plt.get_cmap('hot')
surf = ax.plot_surface(X, Y, posteriors, cmap = my_cmap, edgecolor ='none')
fig.colorbar(surf, ax = ax, shrink = 0.4, aspect = 5)
ax.set_xlabel('Prior')
ax.set_ylabel('Sensitivity')
ax.set_zlabel('Posterior')
plt.show()

# %%
def posteriorFromPriorAndSpecificity(prior, specificity):
    sensitivity = 0.95
    probTruePositive = prior*sensitivity
    probFalsePositive = (1-prior)*(1-specificity)
    probPosTest = probTruePositive+probFalsePositive
    normalizedTruePositive = probTruePositive/probPosTest;
    return normalizedTruePositive

# %%
X, Y = np.meshgrid(priors, specificities)
X,Y
# Out:
# (array([[0.01, 0.02, 0.03, ..., 0.98, 0.99, 1.  ],
#         [0.01, 0.02, 0.03, ..., 0.98, 0.99, 1.  ],
#         [0.01, 0.02, 0.03, ..., 0.98, 0.99, 1.  ],
#         ...,
#         [0.01, 0.02, 0.03, ..., 0.98, 0.99, 1.  ],
#         [0.01, 0.02, 0.03, ..., 0.98, 0.99, 1.  ],
#         [0.01, 0.02, 0.03, ..., 0.98, 0.99, 1.  ]]),
#  array([[0.01, 0.01, 0.01, ..., 0.01, 0.01, 0.01],
#         [0.02, 0.02, 0.02, ..., 0.02, 0.02, 0.02],
#         [0.03, 0.03, 0.03, ..., 0.03, 0.03, 0.03],
#         ...,
#         [0.98, 0.98, 0.98, ..., 0.98, 0.98, 0.98],
#         [0.99, 0.99, 0.99, ..., 0.99, 0.99, 0.99],
#         [1.  , 1.  , 1.  , ..., 1.  , 1.  , 1.  ]]))

# %%
posteriors1 = posteriorFromPriorAndSpecificity(X,Y)

# %%
fig = plt.figure(figsize =(6, 6))
ax = plt.axes(projection ='3d')
my_cmap = plt.get_cmap('hot')
surf = ax.plot_surface(X, Y, posteriors1, cmap = my_cmap, edgecolor ='none')
fig.colorbar(surf, ax = ax, shrink = 0.4, aspect = 5)
ax.set_xlabel('Prior')
ax.set_ylabel('Specificity')
ax.set_zlabel('Posterior')
plt.show()

# %%
def posteriorFromSensitivityAndSpecificity(sensitivity, specificity):
    prior = 0.01
    probTruePositive = prior*sensitivity
    probFalsePositive = (1-prior)*(1-specificity)
    probPosTest = probTruePositive+probFalsePositive
    normalizedTruePositive = probTruePositive/probPosTest;
    return normalizedTruePositive

# %%
X, Y = np.meshgrid(sensitivities, specificities)
X,Y
# Out:
# (array([[0.01, 0.02, 0.03, ..., 0.98, 0.99, 1.  ],
#         [0.01, 0.02, 0.03, ..., 0.98, 0.99, 1.  ],
#         [0.01, 0.02, 0.03, ..., 0.98, 0.99, 1.  ],
#         ...,
#         [0.01, 0.02, 0.03, ..., 0.98, 0.99, 1.  ],
#         [0.01, 0.02, 0.03, ..., 0.98, 0.99, 1.  ],
#         [0.01, 0.02, 0.03, ..., 0.98, 0.99, 1.  ]]),
#  array([[0.01, 0.01, 0.01, ..., 0.01, 0.01, 0.01],
#         [0.02, 0.02, 0.02, ..., 0.02, 0.02, 0.02],
#         [0.03, 0.03, 0.03, ..., 0.03, 0.03, 0.03],
#         ...,
#         [0.98, 0.98, 0.98, ..., 0.98, 0.98, 0.98],
#         [0.99, 0.99, 0.99, ..., 0.99, 0.99, 0.99],
#         [1.  , 1.  , 1.  , ..., 1.  , 1.  , 1.  ]]))

# %%
posteriors2 = posteriorFromSensitivityAndSpecificity(X,Y)

# %%
fig = plt.figure(figsize =(6, 6))
ax = plt.axes(projection ='3d')
my_cmap = plt.get_cmap('hot')
surf = ax.plot_surface(X, Y, posteriors2, cmap = my_cmap, edgecolor ='none')
fig.colorbar(surf, ax = ax, shrink = 0.4, aspect = 5)
ax.set_xlabel('Sensitivity')
ax.set_ylabel('Specificity')
ax.set_zlabel('Posterior')
plt.show()
